# %% [markdown]
# # International football results from 1872 to 2021

# %% [markdown]
# ### Conteúdo do dataset
# Este dataset contém 43.170 resultados de partidas de futebol iniciando desde os primeiros jogos oficiais até os jogos atuais. O dataset abrange partidas oficiais e também partidas amistosas.O dataset não contém resultados dos jogos olímpicos.
#
# ### Objetivo desde notebook
# Este notebook tem o objetivo de fazer uma análise exploratória dos dados, vamos responder algumas perguntas como:

# %% [markdown]
# ## 1. Análise exploratória

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('dados/results.csv')

# %%
data.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
data['year'] = data['date'].str.extract('([0-9]+)\-', expand=False)

# %%
data.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year
# 0  Scotland    False  1872
# 1   England    False  1873
# 2  Scotland    False  1874
# 3   England    False  1875
# 4  Scotland    False  1876

# %%
data = data.sort_values(by='date')

# %%
data.iloc[0:50]
# Out:
#           date         home_team         away_team  home_score  away_score  \
# 0   1872-11-30          Scotland           England           0           0
# 1   1873-03-08           England          Scotland           4           2
# 2   1874-03-07          Scotland           England           2           1
# 3   1875-03-06           England          Scotland           2           2
# 4   1876-03-04          Scotland           England           3           0
# 5   1876-03-25          Scotland             Wales           4           0
# 6   1877-03-03           England          Scotland           1           3
# 7   1877-03-05             Wales          Scotland           0           2
# 8   1878-03-02          Scotland           England           7           2
# 9   1878-03-23          Scotland             Wales           9           0
# 10  1879-01-18           England             Wales           2           1
# 11  1879-04-05           England          Scotland           5           4
# 12  1879-04-07             Wales          Scotland           0           3
# 13  1880-03-13          Scotland           England           5           4
# 14  1880-03-15             Wales           England           2           3
# 15  1880-03-27          Scotland             Wales           5           1
# 16  1881-02-26           England             Wales           0           1
# 17  1881-03-12           England          Scotland           1           6
# 18  1881-03-14             Wales          Scotland           1           5
# 19  1882-02-18  Northern Ireland           England           0          13
# 20  1882-02-25             Wales  Northern Ireland           7           1
# 21  1882-03-11          Scotland           England           5           1
# 22  1882-03-13             Wales           England           5           3
# 23  1882-03-25          Scotland             Wales           5           0
# 24  1883-02-03           England             Wales           5           0
# 25  1883-02-24           England  Northern Ireland           7           0
# 26  1883-03-10           England          Scotland           2           3
# 27  1883-03-12             Wales          Scotland           0           3
# 28  1883-03-17  Northern Ireland             Wales           1           1
# 29  1884-01-26  Northern Ireland          Scotland           0           5
# 30  1884-02-09             Wales  Northern Ireland           6           0
# 31  1884-02-23  Northern Ireland           England           1           8
# 32  1884-03-15          Scotland           England           1           0
# 33  1884-03-17             Wales           England           0           4
# 34  1884-03-29          Scotland             Wales           4           1
# 35  1885-02-28           England  Northern Ireland           4           0
# 36  1885-03-14           England             Wales           1           1
# 37  1885-03-14          Scotland  Northern Ireland           8           2
# 38  1885-03-21           England          Scotland           1           1
# 39  1885-03-23             Wales          Scotland           1           8
# 40  1885-04-11  Northern Ireland             Wales           2           8
# 41  1885-11-28     United States            Canada           0           1
# 42  1886-02-27             Wales  Northern Ireland           5           0
# 43  1886-03-13  Northern Ireland           England           1           6
# 44  1886-03-20  Northern Ireland          Scotland           2           7
# 45  1886-03-27          Scotland           England           1           1
# 46  1886-03-29             Wales           England           1           3
# 47  1886-04-10          Scotland             Wales           4           1
# 48  1886-11-25     United States            Canada           3           2
# 49  1887-02-05           England  Northern Ireland           7           0
#
#               tournament        city        country  neutral  year
# 0               Friendly     Glasgow       Scotland    False  1872
# 1               Friendly      London        England    False  1873
# 2               Friendly     Glasgow       Scotland    False  1874
# 3               Friendly      London        England    False  1875
# 4               Friendly     Glasgow       Scotland    False  1876
# 5               Friendly     Glasgow       Scotland    False  1876
# 6               Friendly      London        England    False  1877
# 7               Friendly     Wrexham          Wales    False  1877
# 8               Friendly     Glasgow       Scotland    False  1878
# 9               Friendly     Glasgow       Scotland    False  1878
# 10              Friendly      London        England    False  1879
# 11              Friendly      London        England    False  1879
# 12              Friendly     Wrexham          Wales    False  1879
# 13              Friendly     Glasgow       Scotland    False  1880
# 14              Friendly     Wrexham          Wales    False  1880
# 15              Friendly     Glasgow       Scotland    False  1880
# 16              Friendly   Blackburn        England    False  1881
# 17              Friendly      London        England    False  1881
# 18              Friendly     Wrexham          Wales    False  1881
# 19              Friendly     Belfast        Ireland    False  1882
# 20              Friendly     Wrexham          Wales    False  1882
# 21              Friendly     Glasgow       Scotland    False  1882
# 22              Friendly     Wrexham          Wales    False  1882
# 23              Friendly     Glasgow       Scotland    False  1882
# 24              Friendly      London        England    False  1883
# 25              Friendly   Liverpool        England    False  1883
# 26              Friendly   Sheffield        England    False  1883
# 27              Friendly     Wrexham          Wales    False  1883
# 28              Friendly     Belfast        Ireland    False  1883
# 29  British Championship     Belfast        Ireland    False  1884
# 30  British Championship     Wrexham          Wales    False  1884
# 31  British Championship     Belfast        Ireland    False  1884
# 32  British Championship     Glasgow       Scotland    False  1884
# 33  British Championship     Wrexham          Wales    False  1884
# 34  British Championship     Glasgow       Scotland    False  1884
# 35  British Championship  Manchester        England    False  1885
# 36  British Championship   Blackburn        England    False  1885
# 37  British Championship     Glasgow       Scotland    False  1885
# 38  British Championship      London        England    False  1885
# 39  British Championship     Wrexham          Wales    False  1885
# 40  British Championship     Belfast        Ireland    False  1885
# 41              Friendly      Newark  United States    False  1885
# 42  British Championship     Wrexham          Wales    False  1886
# 43  British Championship     Belfast        Ireland    False  1886
# 44  British Championship     Belfast        Ireland    False  1886
# 45  British Championship     Glasgow       Scotland    False  1886
# 46  British Championship     Wrexham          Wales    False  1886
# 47  British Championship     Glasgow       Scotland    False  1886
# 48              Friendly      Newark  United States    False  1886
# 49  British Championship   Sheffield        England    False  1887

# %% [markdown]
# Os primeiros cinco jogos oficiais foram disputados entre Scotland e England. Somente a partir do jogo 42 que aconteceu outra partida que não envolvesse Nothern Ireland, England, Scotland e Wales.

# %% [markdown]
# #### 1. Os países que mais jogaram na história

# %%
home = data.home_team.value_counts().to_frame()
away = data.away_team.value_counts().to_frame()

# %%
home['away_qtd'] = away
total = home

# %%
total.reset_index(inplace=True)
total.rename(columns={'index': 'country', 'home_team': 'home_qtd'}, inplace = True)

# %%
total.away_qtd.fillna(0, inplace=True)

# %%
# Estes são os países que mais jogaram jogos como mandantes na história.
total.head(15)
# Out:
#           country  home_qtd  away_qtd
# 0          Brazil       586     421.0
# 1       Argentina       561     442.0
# 2          Mexico       529     369.0
# 3         Germany       521     453.0
# 4         England       516     520.0
# 5          Sweden       501     542.0
# 6          France       496     368.0
# 7     South Korea       489     401.0
# 8         Hungary       470     486.0
# 9           Italy       461     366.0
# 10  United States       438     274.0
# 11        Austria       434     377.0
# 12    Netherlands       433     376.0
# 13        Belgium       425     368.0
# 14    Switzerland       418     404.0

# %%
#Estes são os países que mais jogaram jogos como visitantes na história
total.sort_values(by='away_qtd', ascending=False).head(15)
# Out:
#         country  home_qtd  away_qtd
# 26      Uruguay       355     551.0
# 5        Sweden       501     542.0
# 4       England       516     520.0
# 8       Hungary       470     486.0
# 65     Paraguay       272     466.0
# 3       Germany       521     453.0
# 18       Poland       397     442.0
# 1     Argentina       561     442.0
# 42       Zambia       310     431.0
# 31      Finland       340     428.0
# 0        Brazil       586     421.0
# 16       Norway       409     415.0
# 20     Scotland       391     413.0
# 41       Russia       311     406.0
# 14  Switzerland       418     404.0

# %%
total['total'] = total.loc[total['home_qtd'] >= 0,['home_qtd','away_qtd']].sum(axis=1)

# %%
#Estes são os países que mais jogaram jogos na história
total.sort_values(by='total', ascending=False).head(15)
# Out:
#         country  home_qtd  away_qtd   total
# 5        Sweden       501     542.0  1043.0
# 4       England       516     520.0  1036.0
# 0        Brazil       586     421.0  1007.0
# 1     Argentina       561     442.0  1003.0
# 3       Germany       521     453.0   974.0
# 8       Hungary       470     486.0   956.0
# 26      Uruguay       355     551.0   906.0
# 2        Mexico       529     369.0   898.0
# 7   South Korea       489     401.0   890.0
# 6        France       496     368.0   864.0
# 18       Poland       397     442.0   839.0
# 9         Italy       461     366.0   827.0
# 16       Norway       409     415.0   824.0
# 14  Switzerland       418     404.0   822.0
# 15      Denmark       418     403.0   821.0

# %% [markdown]
# #### 2. Os anos que mais tiverem partidas de futebol

# %%
sns.set(rc={'figure.figsize':(12,8)})
dfYear = data['year'].value_counts()[0:20]
ax = sns.barplot(x=data['year'].value_counts()[0:20], y=dfYear.index, data=data, palette="Blues_d")

# %% [markdown]
# #### 3. Jogos com as maiores quantidades de gols em partidas oficiais

# %%
data['qtd_gols'] = data.loc[data['tournament'] != 'Friendly', ['home_score', 'away_score']].sum(axis=1)

# %%
data[['home_team', 
      'away_team', 
      'home_score', 
      'away_score', 
      'date', 
      'qtd_gols',
      'tournament'
     ]].sort_values(by='qtd_gols', ascending=False).head(20)
# Out:
#             home_team         away_team  home_score  away_score        date  \
# 23923       Australia    American Samoa          31           0  2001-04-11
# 7975           Tahiti      Cook Islands          30           0  1971-09-13
# 11068            Fiji          Kiribati          24           0  1979-08-30
# 28959           Sápmi            Monaco          21           1  2006-11-24
# 23920       Australia             Tonga          22           0  2001-04-09
# 6125            Libya              Oman          21           0  1966-04-03
# 27500            Guam       North Korea           0          21  2005-03-11
# 22694          Kuwait            Bhutan          20           0  2000-02-14
# 25826            Sark     Isle of Wight           0          20  2003-06-30
# 36157          Darfur           Padania           0          20  2014-06-01
# 14846  American Samoa  Papua New Guinea           0          20  1987-12-15
# 25816       Gibraltar              Sark          19           0  2003-06-29
# 36162          Darfur     South Ossetia           0          19  2014-06-02
# 22607        China PR              Guam          19           0  2000-01-26
# 23582            Iran              Guam          19           0  2000-11-24
# 12852            Niue  Papua New Guinea           0          19  1983-08-22
# 16786            Guam     New Caledonia           0          18  1991-09-15
# 34256          Darfur          Provence           0          18  2012-06-05
# 25829      Micronesia     New Caledonia           0          18  2003-07-01
# 25887        Kiribati           Vanuatu           0          18  2003-07-07
#
#        qtd_gols                    tournament
# 23923      31.0  FIFA World Cup qualification
# 7975       30.0           South Pacific Games
# 11068      24.0           South Pacific Games
# 28959      22.0                Viva World Cup
# 23920      22.0  FIFA World Cup qualification
# 6125       21.0                      Arab Cup
# 27500      21.0             EAFF Championship
# 22694      20.0   AFC Asian Cup qualification
# 25826      20.0                  Island Games
# 36157      20.0     CONIFA World Football Cup
# 14846      20.0           South Pacific Games
# 25816      19.0                  Island Games
# 36162      19.0     CONIFA World Football Cup
# 22607      19.0   AFC Asian Cup qualification
# 23582      19.0  FIFA World Cup qualification
# 12852      19.0           South Pacific Games
# 16786      18.0           South Pacific Games
# 34256      18.0                Viva World Cup
# 25829      18.0           South Pacific Games
# 25887      18.0           South Pacific Games

# %% [markdown]
# #### 4. Partidas com as maiores quantidades de gols em Copas do Mundo

# %%
data['qtd_gols'] = data.loc[data['tournament'] == 'FIFA World Cup', ['home_score', 'away_score']].sum(axis=1)

# %%
data.qtd_gols.fillna(0, inplace=True)

# %%
data[['home_team', 
      'away_team', 
      'home_score', 
      'away_score', 
      'date', 
      'qtd_gols',
      'tournament'
     ]].sort_values(by='qtd_gols', ascending=False).head(20)
# Out:
#          home_team      away_team  home_score  away_score        date  \
# 3682   Switzerland        Austria           5           7  1954-06-26
# 2104        Brazil         Poland           6           5  1938-06-05
# 3676       Germany        Hungary           3           8  1954-06-20
# 12399      Hungary    El Salvador          10           1  1982-06-15
# 4375        France       Paraguay           7           3  1958-06-08
# 9119    Yugoslavia       DR Congo           9           0  1974-06-18
# 4405        France        Germany           6           3  1958-06-28
# 3679       Germany         Turkey           7           2  1954-06-23
# 3669       Hungary    South Korea           9           0  1954-06-17
# 1324     Argentina         Mexico           6           3  1930-07-19
# 3667       Belgium        England           4           4  1954-06-17
# 2115          Cuba         Sweden           0           8  1938-06-12
# 36292       Brazil        Germany           1           7  2014-07-08
# 3150        Brazil         Sweden           7           1  1950-07-09
# 24925      Germany   Saudi Arabia           8           0  2002-06-01
# 3144       Bolivia        Uruguay           0           8  1950-07-02
# 1697         Italy  United States           7           1  1934-05-27
# 6268   North Korea       Portugal           3           5  1966-07-23
# 5150      Colombia         Russia           4           4  1962-06-03
# 32305     Portugal    North Korea           7           0  2010-06-21
#
#        qtd_gols      tournament
# 3682       12.0  FIFA World Cup
# 2104       11.0  FIFA World Cup
# 3676       11.0  FIFA World Cup
# 12399      11.0  FIFA World Cup
# 4375       10.0  FIFA World Cup
# 9119        9.0  FIFA World Cup
# 4405        9.0  FIFA World Cup
# 3679        9.0  FIFA World Cup
# 3669        9.0  FIFA World Cup
# 1324        9.0  FIFA World Cup
# 3667        8.0  FIFA World Cup
# 2115        8.0  FIFA World Cup
# 36292       8.0  FIFA World Cup
# 3150        8.0  FIFA World Cup
# 24925       8.0  FIFA World Cup
# 3144        8.0  FIFA World Cup
# 1697        8.0  FIFA World Cup
# 6268        8.0  FIFA World Cup
# 5150        8.0  FIFA World Cup
# 32305       7.0  FIFA World Cup

# %%
data.drop(columns=['qtd_gols'], inplace=True)

# %% [markdown]
# #### 5. Países que mais fizeram gols em Copas do Mundo

# %%
home = data.loc[data.tournament == 'FIFA World Cup', ['home_team', 'home_score']]
away = data.loc[data.tournament == 'FIFA World Cup', ['away_team', 'away_score']]

# %%
home = home.groupby("home_team")["home_score"].count().to_frame()
away = away.groupby("away_team")["away_score"].count().to_frame()

# %%
home['away_score'] = away
total = home

# %%
total.reset_index(inplace=True)

# %%
total.rename(columns={'home_team': 'country'}, inplace = True)

# %%
total['total_gols'] = total.loc[total['home_score'] >= 0, ['home_score', 'away_score']].sum(axis=1)

# %%
total.drop(columns=['home_score', 'away_score'], inplace=True)

# %%
total.sort_values(by='total_gols', ascending=False).head(25)
# Out:
#            country  total_gols
# 8           Brazil       109.0
# 28         Germany       109.0
# 38           Italy        83.0
# 2        Argentina        81.0
# 25         England        69.0
# 26          France        66.0
# 66           Spain        63.0
# 42          Mexico        57.0
# 76         Uruguay        56.0
# 67          Sweden        51.0
# 44     Netherlands        50.0
# 5          Belgium        48.0
# 57          Russia        45.0
# 68     Switzerland        37.0
# 53          Poland        34.0
# 65     South Korea        34.0
# 77      Yugoslavia        33.0
# 75   United States        33.0
# 12           Chile        33.0
# 33         Hungary        32.0
# 19  Czechoslovakia        30.0
# 54        Portugal        30.0
# 4          Austria        29.0
# 51        Paraguay        27.0
# 9         Bulgaria        26.0

# %% [markdown]
# #### 6. Cidades que mais receberam partidas oficiais e não oficiais

# %%
data.city.value_counts().to_frame().head(10)
# Out:
#               city
# Kuala Lumpur   667
# Doha           490
# Bangkok        427
# London         416
# Budapest       404
# Montevideo     358
# Kuwait City    349
# Vienna         344
# Copenhagen     336
# Glasgow        334

# %% [markdown]
# #### 7. Cidades que mais receberam partidas oficiais

# %%
data2 = data.loc[data['tournament'] != 'Friendly', 'city']

# %%
data2.value_counts().to_frame().head(10)
# Out:
#               city
# Kuala Lumpur   607
# Bangkok        366
# Doha           293
# Montevideo     260
# Belfast        245
# Glasgow        243
# Buenos Aires   235
# Kuwait City    218
# Seoul          212
# Santiago       212

# %% [markdown]
# #### 8. Países que mais receberam partidas oficiais e não oficiais

# %%
data.country.value_counts().to_frame().head(10)
# Out:
#                       country
# United States            1237
# France                    818
# Malaysia                  744
# England                   717
# Sweden                    655
# Germany                   602
# Brazil                    567
# Qatar                     546
# Spain                     541
# United Arab Emirates      532

# %% [markdown]
# #### 9. Países que mais receberam partidas oficiais

# %%
data2 = data.loc[data['tournament'] != 'Friendly', 'country']
data2.value_counts().to_frame().head(10)
# Out:
#                country
# Malaysia           657
# United States      584
# England            431
# Thailand           409
# South Africa       400
# Sweden             394
# Brazil             373
# France             347
# South Korea        335
# Qatar              335

# %%
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year
# 0  Scotland    False  1872
# 1   England    False  1873
# 2  Scotland    False  1874
# 3   England    False  1875
# 4  Scotland    False  1876
